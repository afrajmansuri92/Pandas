# %%
import numpy as np
import pandas as pd

# %%
data =pd.read_csv('/matches - matches.csv')

# %%
data
# Out:
#       id  season       city  ...          umpire1          umpire2 umpire3
# 0      1    2017  Hyderabad  ...      AY Dandekar         NJ Llong     NaN
# 1      2    2017       Pune  ...   A Nand Kishore           S Ravi     NaN
# 2      3    2017     Rajkot  ...      Nitin Menon        CK Nandan     NaN
# 3      4    2017     Indore  ...     AK Chaudhary    C Shamshuddin     NaN
# 4      5    2017  Bangalore  ...              NaN              NaN     NaN
# ..   ...     ...        ...  ...              ...              ...     ...
# 631  632    2016     Raipur  ...   A Nand Kishore     BNJ Oxenford     NaN
# 632  633    2016  Bangalore  ...     AK Chaudhary  HDPK Dharmasena     NaN
# 633  634    2016      Delhi  ...        M Erasmus    C Shamshuddin     NaN
# 634  635    2016      Delhi  ...        M Erasmus        CK Nandan     NaN
# 635  636    2016  Bangalore  ...  HDPK Dharmasena     BNJ Oxenford     NaN
#
# [636 rows x 18 columns]

# %%
data.head(3)
# Out:
#    id  season       city  ...         umpire1    umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar   NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore     S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon  CK Nandan     NaN
#
# [3 rows x 18 columns]

# %%
data.tail()
# Out:
#       id  season       city  ...          umpire1          umpire2 umpire3
# 631  632    2016     Raipur  ...   A Nand Kishore     BNJ Oxenford     NaN
# 632  633    2016  Bangalore  ...     AK Chaudhary  HDPK Dharmasena     NaN
# 633  634    2016      Delhi  ...        M Erasmus    C Shamshuddin     NaN
# 634  635    2016      Delhi  ...        M Erasmus        CK Nandan     NaN
# 635  636    2016  Bangalore  ...  HDPK Dharmasena     BNJ Oxenford     NaN
#
# [5 rows x 18 columns]

# %%
data.shape
# Out:
# (636, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
#  17  umpire3          0 non-null      float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 89.6+ KB

# %%
data.describe()
# Out:
#                id       season  ...  win_by_wickets  umpire3
# count  636.000000   636.000000  ...      636.000000      0.0
# mean   318.500000  2012.490566  ...        3.372642      NaN
# std    183.741666     2.773026  ...        3.420338      NaN
# min      1.000000  2008.000000  ...        0.000000      NaN
# 25%    159.750000  2010.000000  ...        0.000000      NaN
# 50%    318.500000  2012.000000  ...        4.000000      NaN
# 75%    477.250000  2015.000000  ...        7.000000      NaN
# max    636.000000  2017.000000  ...       10.000000      NaN
#
# [8 rows x 6 columns]

# %%
data['winner'].shape
# Out:
# (636,)

# %%
data[['team1','team2','winner']]
# Out:
#                            team1  ...                       winner
# 0            Sunrisers Hyderabad  ...          Sunrisers Hyderabad
# 1                 Mumbai Indians  ...       Rising Pune Supergiant
# 2                  Gujarat Lions  ...        Kolkata Knight Riders
# 3         Rising Pune Supergiant  ...              Kings XI Punjab
# 4    Royal Challengers Bangalore  ...  Royal Challengers Bangalore
# ..                           ...  ...                          ...
# 631             Delhi Daredevils  ...  Royal Challengers Bangalore
# 632                Gujarat Lions  ...  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad  ...          Sunrisers Hyderabad
# 634                Gujarat Lions  ...          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  ...          Sunrisers Hyderabad
#
# [636 rows x 3 columns]

# %%
data.iloc[1:11:2]
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 5   6    2017  Hyderabad  ...      A Deshmukh       NJ Llong     NaN
# 7   8    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 9  10    2017     Mumbai  ...     Nitin Menon      CK Nandan     NaN
#
# [5 rows x 18 columns]

# %%
data.iloc[:,[4,5,10]]
# Out:
#                            team1  ...                       winner
# 0            Sunrisers Hyderabad  ...          Sunrisers Hyderabad
# 1                 Mumbai Indians  ...       Rising Pune Supergiant
# 2                  Gujarat Lions  ...        Kolkata Knight Riders
# 3         Rising Pune Supergiant  ...              Kings XI Punjab
# 4    Royal Challengers Bangalore  ...  Royal Challengers Bangalore
# ..                           ...  ...                          ...
# 631             Delhi Daredevils  ...  Royal Challengers Bangalore
# 632                Gujarat Lions  ...  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad  ...          Sunrisers Hyderabad
# 634                Gujarat Lions  ...          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  ...          Sunrisers Hyderabad
#
# [636 rows x 3 columns]

# %%
 mask = data['city']=='Hyderabad'

# %%
data[mask]
# Out:
#       id  season       city  ...                umpire1          umpire2 umpire3
# 0      1    2017  Hyderabad  ...            AY Dandekar         NJ Llong     NaN
# 5      6    2017  Hyderabad  ...             A Deshmukh         NJ Llong     NaN
# 18    19    2017  Hyderabad  ...            AY Dandekar       A Deshmukh     NaN
# 20    21    2017  Hyderabad  ...            CB Gaffaney         NJ Llong     NaN
# 35    36    2017  Hyderabad  ...            AY Dandekar           S Ravi     NaN
# 42    43    2017  Hyderabad  ...  KN Ananthapadmanabhan     AK Chaudhary     NaN
# 46    47    2017  Hyderabad  ...  KN Ananthapadmanabhan        M Erasmus     NaN
# 58    59    2017  Hyderabad  ...               NJ Llong           S Ravi     NaN
# 65    66    2008  Hyderabad  ...              IL Howell        AM Saheba     NaN
# 67    68    2008  Hyderabad  ...              Asad Rauf        MR Benson     NaN
# 76    77    2008  Hyderabad  ...            BR Doctrove        RB Tiffin     NaN
# 79    80    2008  Hyderabad  ...              Asad Rauf      RE Koertzen     NaN
# 91    92    2008  Hyderabad  ...              IL Howell        AM Saheba     NaN
# 101  102    2008  Hyderabad  ...            BR Doctrove        DJ Harper     NaN
# 113  114    2008  Hyderabad  ...             BG Jerling        AM Saheba     NaN
# 235  236    2011  Hyderabad  ...            RE Koertzen      SK Tarapore     NaN
# 244  245    2011  Hyderabad  ...            RE Koertzen           S Ravi     NaN
# 248  249    2011  Hyderabad  ...            RE Koertzen           S Ravi     NaN
# 259  260    2011  Hyderabad  ...        HDPK Dharmasena          AL Hill     NaN
# 274  275    2011  Hyderabad  ...               S Asnani        RJ Tucker     NaN
# 278  279    2011  Hyderabad  ...              Asad Rauf        AM Saheba     NaN
# 285  286    2011  Hyderabad  ...              Asad Rauf        AM Saheba     NaN
# 330  331    2012  Hyderabad  ...              JD Cloete       SJA Taufel     NaN
# 358  359    2012  Hyderabad  ...        HDPK Dharmasena     BNJ Oxenford     NaN
# 372  373    2012  Hyderabad  ...                 S Ravi       SJA Taufel     NaN
# 375  376    2012  Hyderabad  ...                 S Ravi       SJA Taufel     NaN
# 383  384    2013  Hyderabad  ...                 S Ravi       SJA Taufel     NaN
# 387  388    2013  Hyderabad  ...           AK Chaudhary           S Ravi     NaN
# 404  405    2013  Hyderabad  ...        HDPK Dharmasena        CK Nandan     NaN
# 422  423    2013  Hyderabad  ...              Asad Rauf         S Asnani     NaN
# 427  428    2013  Hyderabad  ...              Asad Rauf         S Asnani     NaN
# 434  435    2013  Hyderabad  ...                  S Das         NJ Llong     NaN
# 448  449    2013  Hyderabad  ...              Asad Rauf     AK Chaudhary     NaN
# 452  453    2013  Hyderabad  ...              Asad Rauf         S Asnani     NaN
# 492  493    2014  Hyderabad  ...        HDPK Dharmasena      VA Kulkarni     NaN
# 495  496    2014  Hyderabad  ...            VA Kulkarni        PG Pathak     NaN
# 499  500    2014  Hyderabad  ...               NJ Llong        CK Nandan     NaN
# 502  503    2014  Hyderabad  ...           AK Chaudhary         NJ Llong     NaN
# 550  551    2015  Hyderabad  ...           AK Chaudhary     K Srinivasan     NaN
# 563  564    2015  Hyderabad  ...           AK Chaudhary  HDPK Dharmasena     NaN
# 567  568    2015  Hyderabad  ...           AK Chaudhary  HDPK Dharmasena     NaN
# 571  572    2015  Hyderabad  ...            CB Gaffaney        K Srinath     NaN
# 583  584    2016  Hyderabad  ...           AK Chaudhary        CK Nandan     NaN
# 587  588    2016  Hyderabad  ...        HDPK Dharmasena        VK Sharma     NaN
# 593  594    2016  Hyderabad  ...           AK Chaudhary        CK Nandan     NaN
# 597  598    2016  Hyderabad  ...            AY Dandekar        CK Nandan     NaN
# 602  603    2016  Hyderabad  ...           AK Chaudhary  HDPK Dharmasena     NaN
# 609  610    2016  Hyderabad  ...              M Erasmus           S Ravi     NaN
# 617  618    2016  Hyderabad  ...             K Bharatan        M Erasmus     NaN
#
# [49 rows x 18 columns]

# %%
data[mask].shape[0]
# Out:
# 49

# %%
def get_city_match_count(city):
  mask = data['city'] == city
  return data[mask].shape[0]

# %%
get_city_match_count('Rajkot')
# Out:
# 10

# %%
mask1 = data['city'] == 'Hyderabad'
mask2 = data['date'] > '2010-01-01'
data[mask1 & mask2].shape[0]
# Out:
# 42

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data['winner'].value_counts().head().plot(kind='bar')

# %%
data['toss_decision'].value_counts().plot(kind='pie')

# %%
data['win_by_runs'].plot(kind='hist')

# %%
myseries = data['winner'].value_counts()

# %%
myseries
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
myseries.index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object')

# %%
myseries.values
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5])

# %%
(data['team2'].value_counts()+ data['team1'].value_counts()).sort_values(ascending = False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kolkata Knight Riders          148
# Kings XI Punjab                148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# dtype: int64

# %%
data.sort_values('city')
# Out:
#       id  season       city  ...          umpire1         umpire2 umpire3
# 460  461    2014  Abu Dhabi  ...        BF Bowden  RK Illingworth     NaN
# 471  472    2014  Abu Dhabi  ...  HDPK Dharmasena  RK Illingworth     NaN
# 470  471    2014  Abu Dhabi  ...  HDPK Dharmasena   C Shamshuddin     NaN
# 464  465    2014  Abu Dhabi  ...   RK Illingworth   C Shamshuddin     NaN
# 459  460    2014  Abu Dhabi  ...   RK Illingworth   C Shamshuddin     NaN
# ..   ...     ...        ...  ...              ...             ...     ...
# 466  467    2014        NaN  ...  HDPK Dharmasena  RK Illingworth     NaN
# 468  469    2014        NaN  ...        M Erasmus          S Ravi     NaN
# 469  470    2014        NaN  ...        BF Bowden       M Erasmus     NaN
# 474  475    2014        NaN  ...        BF Bowden          S Ravi     NaN
# 476  477    2014        NaN  ...  HDPK Dharmasena       M Erasmus     NaN
#
# [636 rows x 18 columns]

# %%
data.sort_values(['city','date'])
# Out:
#       id  season       city  ...          umpire1         umpire2 umpire3
# 457  458    2014  Abu Dhabi  ...        M Erasmus  RK Illingworth     NaN
# 459  460    2014  Abu Dhabi  ...   RK Illingworth   C Shamshuddin     NaN
# 460  461    2014  Abu Dhabi  ...        BF Bowden  RK Illingworth     NaN
# 464  465    2014  Abu Dhabi  ...   RK Illingworth   C Shamshuddin     NaN
# 470  471    2014  Abu Dhabi  ...  HDPK Dharmasena   C Shamshuddin     NaN
# ..   ...     ...        ...  ...              ...             ...     ...
# 466  467    2014        NaN  ...  HDPK Dharmasena  RK Illingworth     NaN
# 468  469    2014        NaN  ...        M Erasmus          S Ravi     NaN
# 469  470    2014        NaN  ...        BF Bowden       M Erasmus     NaN
# 474  475    2014        NaN  ...        BF Bowden          S Ravi     NaN
# 476  477    2014        NaN  ...  HDPK Dharmasena       M Erasmus     NaN
#
# [636 rows x 18 columns]

# %%
data
# Out:
#       id  season       city  ...          umpire1          umpire2 umpire3
# 0      1    2017  Hyderabad  ...      AY Dandekar         NJ Llong     NaN
# 1      2    2017       Pune  ...   A Nand Kishore           S Ravi     NaN
# 2      3    2017     Rajkot  ...      Nitin Menon        CK Nandan     NaN
# 3      4    2017     Indore  ...     AK Chaudhary    C Shamshuddin     NaN
# 4      5    2017  Bangalore  ...              NaN              NaN     NaN
# ..   ...     ...        ...  ...              ...              ...     ...
# 631  632    2016     Raipur  ...   A Nand Kishore     BNJ Oxenford     NaN
# 632  633    2016  Bangalore  ...     AK Chaudhary  HDPK Dharmasena     NaN
# 633  634    2016      Delhi  ...        M Erasmus    C Shamshuddin     NaN
# 634  635    2016      Delhi  ...        M Erasmus        CK Nandan     NaN
# 635  636    2016  Bangalore  ...  HDPK Dharmasena     BNJ Oxenford     NaN
#
# [636 rows x 18 columns]

# %%
data.drop_duplicates(subset=['city']).shape
# Out:
# (31, 18)

# %%
data
# Out:
#       id  season       city  ...          umpire1          umpire2 umpire3
# 0      1    2017  Hyderabad  ...      AY Dandekar         NJ Llong     NaN
# 1      2    2017       Pune  ...   A Nand Kishore           S Ravi     NaN
# 2      3    2017     Rajkot  ...      Nitin Menon        CK Nandan     NaN
# 3      4    2017     Indore  ...     AK Chaudhary    C Shamshuddin     NaN
# 4      5    2017  Bangalore  ...              NaN              NaN     NaN
# ..   ...     ...        ...  ...              ...              ...     ...
# 631  632    2016     Raipur  ...   A Nand Kishore     BNJ Oxenford     NaN
# 632  633    2016  Bangalore  ...     AK Chaudhary  HDPK Dharmasena     NaN
# 633  634    2016      Delhi  ...        M Erasmus    C Shamshuddin     NaN
# 634  635    2016      Delhi  ...        M Erasmus        CK Nandan     NaN
# 635  636    2016  Bangalore  ...  HDPK Dharmasena     BNJ Oxenford     NaN
#
# [636 rows x 18 columns]

# %%
data.drop_duplicates('season', keep='last')[['season','winner']].sort
# Out:
#      season                 winner
# 58     2017         Mumbai Indians
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
